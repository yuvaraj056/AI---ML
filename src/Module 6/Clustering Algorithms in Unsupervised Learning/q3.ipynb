# %%
# Question 2: Implementing Hierarchical Clustering
# Description: Use Hierarchical Clustering on a dataset and visualize the dendrogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs
# Create sample data with 4 clusters
X, y = make_blobs(n_samples=150, centers=4, cluster_std=1.0, random_state=42)

# Visualize raw data
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title("Synthetic Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Perform hierarchical/agglomerative clustering
Z = linkage(X, method='ward')  # 'ward' minimizes variance within clusters
plt.figure(figsize=(12, 6))
dendrogram(Z)
plt.title("Dendrogram for Hierarchical Clustering")
plt.xlabel("Data Point Index")
plt.ylabel("Euclidean Distance")
plt.show()
